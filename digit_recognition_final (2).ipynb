# %%
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, AveragePooling2D
from keras import backend as K

# the data, split between train and test sets
(x_train, y_train), (x_test, y_test) = mnist.load_data()
num_classes=10
print(x_train.shape, y_train.shape)
x_train = x_train.reshape(x_train.shape[0], 28, 28, 1)
x_test = x_test.reshape(x_test.shape[0], 28, 28, 1)
input_shape = (28, 28, 1)

# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255.0
x_test /= 255.0
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# (60000, 28, 28) (60000,)
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples

# %%
batch_size = 128
epochs = 50

model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3),activation='relu',input_shape=input_shape))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(AveragePooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss=keras.losses.categorical_crossentropy,optimizer=keras.optimizers.Adadelta(),metrics=['accuracy'])

# %%
hist = model.fit(x_train, y_train,batch_size=batch_size,epochs=epochs,verbose=1,validation_data=(x_test, y_test))
print("The model has successfully trained")

model.save('mnist.h5')
print("Saving the model as mnist.h5")
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Epoch 1/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 49s 98ms/step - accuracy: 0.1179 - loss: 2.2990 - val_accuracy: 0.2355 - val_loss: 2.2795
# Epoch 2/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 45s 96ms/step - accuracy: 0.2283 - loss: 2.2749 - val_accuracy: 0.3116 - val_loss: 2.2387
# Epoch 3/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 46s 98ms/step - accuracy: 0.2881 - loss: 2.2296 - val_accuracy: 0.4336 - val_loss: 2.1583
# Epoch 4/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 46s 98ms/step - accuracy: 0.4182 - loss: 2.1352 - val_accuracy: 0.6006 - val_loss: 1.9788
# Epoch 5/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 46s 99ms/step - accuracy: 0.5885 - loss: 1.9254 - val_accuracy: 0.7175 - val_loss: 1.5819
# Epoch 6/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 47s 100ms/step - accuracy: 0.7006 - loss: 1.4895 - val_accuracy: 0.7966 - val_loss: 1.0049
# Epoch 7/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 47s 99ms/step - accuracy: 0.7872 - loss: 0.9519 - val_accuracy: 0.8406 - val_loss: 0.6663
# Epoch 8/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 47s 100ms/step - accuracy: 0.8245 - loss: 0.6841 - val_accuracy: 0.8632 - val_loss: 0.5300
# Epoch 9/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 46s 99ms/step - accuracy: 0.8479 - loss: 0.5626 - val_accuracy: 0.8785 - val_loss: 0.4626
# Epoch 10/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 49s 104ms/step - accuracy: 0.8603 - loss: 0.5052 - val_accuracy: 0.8875 - val_loss: 0.4217
# Epoch 11/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 45s 96ms/step - accuracy: 0.8717 - loss: 0.4596 - val_accuracy: 0.8928 - val_loss: 0.3935
# Epoch 12/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 45s 97ms/step - accuracy: 0.8802 - loss: 0.4280 - val_accuracy: 0.8978 - val_loss: 0.3735
# Epoch 13/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 46s 97ms/step - accuracy: 0.8820 - loss: 0.4124 - val_accuracy: 0.9026 - val_loss: 0.3577
# Epoch 14/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 45s 96ms/step - accuracy: 0.8874 - loss: 0.3971 - val_accuracy: 0.9043 - val_loss: 0.3442
# Epoch 15/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 47s 100ms/step - accuracy: 0.8917 - loss: 0.3839 - val_accuracy: 0.9067 - val_loss: 0.3327
# Epoch 16/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 47s 100ms/step - accuracy: 0.8929 - loss: 0.3691 - val_accuracy: 0.9087 - val_loss: 0.3230
# Epoch 17/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 51s 109ms/step - accuracy: 0.8944 - loss: 0.3668 - val_accuracy: 0.9108 - val_loss: 0.3140
# Epoch 18/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 53s 113ms/step - accuracy: 0.8965 - loss: 0.3535 - val_accuracy: 0.9127 - val_loss: 0.3056
# Epoch 19/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 48s 103ms/step - accuracy: 0.9019 - loss: 0.3409 - val_accuracy: 0.9158 - val_loss: 0.2988
# Epoch 20/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 49s 104ms/step - accuracy: 0.9034 - loss: 0.3324 - val_accuracy: 0.9179 - val_loss: 0.2924
# Epoch 21/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 47s 100ms/step - accuracy: 0.9023 - loss: 0.3303 - val_accuracy: 0.9181 - val_loss: 0.2856
# Epoch 22/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 80s 96ms/step - accuracy: 0.9071 - loss: 0.3231 - val_accuracy: 0.9190 - val_loss: 0.2800
# Epoch 23/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 46s 98ms/step - accuracy: 0.9064 - loss: 0.3150 - val_accuracy: 0.9204 - val_loss: 0.2739
# Epoch 24/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 45s 96ms/step - accuracy: 0.9103 - loss: 0.3095 - val_accuracy: 0.9223 - val_loss: 0.2686
# Epoch 25/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 47s 99ms/step - accuracy: 0.9120 - loss: 0.3021 - val_accuracy: 0.9242 - val_loss: 0.2633
# Epoch 26/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 45s 95ms/step - accuracy: 0.9139 - loss: 0.3031 - val_accuracy: 0.9253 - val_loss: 0.2583
# Epoch 27/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 45s 96ms/step - accuracy: 0.9146 - loss: 0.2895 - val_accuracy: 0.9265 - val_loss: 0.2534
# Epoch 28/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 45s 96ms/step - accuracy: 0.9176 - loss: 0.2841 - val_accuracy: 0.9280 - val_loss: 0.2490
# Epoch 29/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 45s 97ms/step - accuracy: 0.9191 - loss: 0.2804 - val_accuracy: 0.9291 - val_loss: 0.2443
# Epoch 30/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 46s 97ms/step - accuracy: 0.9184 - loss: 0.2804 - val_accuracy: 0.9297 - val_loss: 0.2406
# Epoch 31/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 45s 96ms/step - accuracy: 0.9191 - loss: 0.2714 - val_accuracy: 0.9302 - val_loss: 0.2372
# Epoch 32/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 46s 97ms/step - accuracy: 0.9224 - loss: 0.2668 - val_accuracy: 0.9322 - val_loss: 0.2327
# Epoch 33/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 45s 97ms/step - accuracy: 0.9247 - loss: 0.2582 - val_accuracy: 0.9327 - val_loss: 0.2286
# Epoch 34/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 45s 97ms/step - accuracy: 0.9230 - loss: 0.2624 - val_accuracy: 0.9330 - val_loss: 0.2254
# Epoch 35/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 47s 99ms/step - accuracy: 0.9244 - loss: 0.2544 - val_accuracy: 0.9340 - val_loss: 0.2215
# Epoch 36/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 46s 98ms/step - accuracy: 0.9265 - loss: 0.2507 - val_accuracy: 0.9356 - val_loss: 0.2183
# Epoch 37/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 46s 97ms/step - accuracy: 0.9260 - loss: 0.2525 - val_accuracy: 0.9361 - val_loss: 0.2156
# Epoch 38/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 45s 96ms/step - accuracy: 0.9284 - loss: 0.2455 - val_accuracy: 0.9378 - val_loss: 0.2109
# Epoch 39/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 46s 98ms/step - accuracy: 0.9288 - loss: 0.2436 - val_accuracy: 0.9394 - val_loss: 0.2085
# Epoch 40/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 46s 97ms/step - accuracy: 0.9310 - loss: 0.2347 - val_accuracy: 0.9407 - val_loss: 0.2052
# Epoch 41/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 47s 100ms/step - accuracy: 0.9307 - loss: 0.2380 - val_accuracy: 0.9408 - val_loss: 0.2032
# Epoch 42/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 68s 144ms/step - accuracy: 0.9307 - loss: 0.2338 - val_accuracy: 0.9420 - val_loss: 0.1998
# Epoch 43/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 71s 151ms/step - accuracy: 0.9350 - loss: 0.2257 - val_accuracy: 0.9418 - val_loss: 0.1976
# Epoch 44/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 71s 151ms/step - accuracy: 0.9352 - loss: 0.2231 - val_accuracy: 0.9436 - val_loss: 0.1947
# Epoch 45/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 71s 151ms/step - accuracy: 0.9342 - loss: 0.2256 - val_accuracy: 0.9440 - val_loss: 0.1918
# Epoch 46/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 71s 152ms/step - accuracy: 0.9361 - loss: 0.2188 - val_accuracy: 0.9459 - val_loss: 0.1893
# Epoch 47/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 71s 151ms/step - accuracy: 0.9370 - loss: 0.2151 - val_accuracy: 0.9455 - val_loss: 0.1876
# Epoch 48/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 71s 151ms/step - accuracy: 0.9377 - loss: 0.2090 - val_accuracy: 0.9458 - val_loss: 0.1845
# Epoch 49/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 71s 152ms/step - accuracy: 0.9374 - loss: 0.2112 - val_accuracy: 0.9469 - val_loss: 0.1823
# Epoch 50/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 71s 151ms/step - accuracy: 0.9387 - loss: 0.2067 - val_accuracy: 0.9478 - val_loss: 0.1798
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# The model has successfully trained
# Saving the model as mnist.h5
# Test loss: 0.17984262108802795
# Test accuracy: 0.9477999806404114

# %%
from keras.models import load_model
from tkinter import *
import tkinter as tk
import win32gui
from PIL import ImageGrab, Image
import numpy as np

model = load_model('mnist.h5')

def predict_digit(img):
    #resize image to 28x28 pixels
    img = img.resize((28,28))
    #convert rgb to grayscale
    img = img.convert('L')
    img = np.array(img)
    #reshaping to support our model input and normalizing
    img = img.reshape(1,28,28,1)
    img = img/255.0
    #predicting the class
    res = model.predict(img)[0]
    print(res)
    return np.argmax(res), max(res)

class App(tk.Tk):
    def __init__(self):
        tk.Tk.__init__(self)

        self.x = self.y = 0
        
        # Creating elements
        self.canvas = tk.Canvas(self, width=300, height=300, bg = "white", cursor="cross")
        self.label = tk.Label(self, text="Draw..", font=("Helvetica", 48))
        self.classify_btn = tk.Button(self, text = "Recognise", command = self.classify_handwriting)   
        self.button_clear = tk.Button(self, text = "Clear", command = self.clear_all)
       
        # Grid structure
        self.canvas.grid(row=0, column=0, pady=2, sticky=W, )
        self.label.grid(row=0, column=1,pady=2, padx=2)
        self.classify_btn.grid(row=1, column=1, pady=2, padx=2)
        self.button_clear.grid(row=1, column=0, pady=2)
        
        #self.canvas.bind("<Motion>", self.start_pos)
        self.canvas.bind("<B1-Motion>", self.draw_lines)

    def clear_all(self):
        self.canvas.delete("all")
        
    def classify_handwriting(self):
        HWND = self.canvas.winfo_id()  # get the handle of the canvas
        rect = win32gui.GetWindowRect(HWND)  # get the coordinate of the canvas
        a,b,c,d = rect
        rect=(a+4,b+4,c-4,d-4)
        im = ImageGrab.grab(rect)

        digit, acc = predict_digit(im)
        self.label.configure(text= str(digit)+', '+ str(int(acc*100))+'%')

    def draw_lines(self, event):
        self.x = event.x
        self.y = event.y
        r=8
        self.canvas.create_oval(self.x-r, self.y-r, self.x + r, self.y + r, fill='black')
       
app = App()
mainloop()
